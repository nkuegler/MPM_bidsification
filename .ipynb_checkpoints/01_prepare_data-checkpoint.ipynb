# %% [markdown]
# ## 0 - Introduction

# %% [markdown]
# This tutorial will gide through the `prepation` step, where
# a generic human-organized (or even desorganized) dataset
# will be automatically origanized into a more standard form.
#
# This prepared (organized) dataset in one hand will help
# `bidsme` to retrieve and discover data, and on another hand
# will allow user to modifiy data (convert to another format)
# without fearing to overwrite original data.
#
# But first, we need load the paths to example dataset
# defined in [dataset installation](./00-tutoral-paths.ipynb):

# %%
# %run "./Configuration/00-tutorial-paths.py"
# Out:
# Dataset path: True
# Source path: True
# Prepared path: True
# Bidsified path: True

# %% [markdown]
# If you see any error, please verify the path definitions in `../01-installation/00-paths.ipynb`.

# %% [markdown]
# We will also need a helper functions, defined in [Tools folder](../Tools/tools.py),
# we just need to execute the file:

# %%
# %run "../Tools/tools.py"

# %% [markdown]
# This will make `clean_data` function aviable:

# %%
# ?clean_data

# %% [markdown]
# We will use this function to reset the prepared datasets.

# %% [markdown]
# Finally we will initialize `bidsme` and get the `logger` object
# which which will control the logging of all bidsme functions:will control the logging of all bidsme functions:

# %%
import bidsme
logger = bidsme.init()
# Out:
# main(81) - INFO
# main(82) - INFO -------------- START bidsme ----------------
# main(83) - INFO Mon Oct 28 14:22:23 2024
# main(84) - INFO version: 1.8.1
# bidsme.schema.BIDSschema(670) - INFO Loaded BIDS schema version 1.10.0

# %% [markdown]
# If the bidsme is installed in current environment, you should see
# the version of `bidsme`.

# %% [markdown]
# ## 1 - Preparation of the dataset

# %% [markdown]
# In order to bidsify a given dataset, it must first be "prepared",
# i.e. put in a standardised format that bidsme expects.
#
# To do so a `bidsme.prepare()` function should be executed on the dataset.

# %% [markdown]
# ### Basic usage

# %% [markdown]
# The `prepare` contains several options and parameters to accomodate a large variety of datasets:

# %%
help(bidsme.prepare)
# Out:
# Help on function prepare in module bidsme.prepare:
#
# prepare(
#     source: str,
#     destination: str,
#     plugin_file: str = '',
#     plugin_opt: dict = {},
#     sub_list: list = [],
#     sub_skip_tsv: bool = False,
#     sub_skip_dir: bool = False,
#     ses_skip_dir: bool = False,
#     part_template: str = '',
#     sub_prefix: str = '',
#     ses_prefix: str = '',
#     sub_no_dir: bool = False,
#     ses_no_dir: bool = False,
#     data_dirs: dict = {},
#     dry_run: bool = False
# ) -> None
#     Prepare data from surce folder and place it in
#     sestination folder.
#
#     Source folder is expected to have structure
#     source/[subId/][sesId/][data/]file.
#     Absence of subId and sesId levels must be communicated
#     via sub_no_dir and ses_no_dir options. List of data
#     folders must be given in data_dirs.
#
#     Prepeared data will have structure
#     destination/sub-<subId>/ses-<sesId>/<type>/<sequence>/file
#
#     A list of treated subjects will be created/updated
#     in destination/participants.tsv file
#
#     Parameters
#     ----------
#     source: str
#         folder containing source dataset
#     destination: str
#         folder for prepeared dataset
#     plugin_file: str
#         path to the plugin file to use
#     plugin_opt: dict
#         named options passed to plugin
#     sub_list: list
#         list of subject to process. Subjects
#         are checked after plugin and must
#         start with 'sub-', as in destination
#         folder
#     sub_skip_tsv: bool
#         if set to True, subjects found in
#         destination/participants.tsv will be
#         ignored
#     sub_skip_dir: bool
#         if set to true, subjects with already
#         created directories will be ignored
#         Can conflict with sub_no_dir
#     ses_skip_dir: bool
#         if set to True, sessions with already
#         created directories will be ignored
#         Can conflict with ses_no_dir
#     part_template: str
#         path to template json file, from whitch
#         participants.tsv will be modeled. Must be
#         formated as usual BIDS sidecar json file
#         for tsv files
#     sub_prefix: str
#         prefix for subject folders in source dataset.
#         If set, subject folders without prefix will
#         be ignored, and will be stripped from subject
#         Ids: sub001 -> 001 if sub_prefix==sub
#         Option has no effect if sub_no_dir==True
#     ses_prefix: str
#         prefix for session folders in source dataset.
#         If set, session folders without prefix will
#         be ignored, and will be stripped from session
#         Ids: sesTest -> Test if ses_prefix==ses
#         Option has no effect if ses_no_dir==True
#     sub_no_dir: bool
#         if set to True, source dataset will not be
#         expected to have subject folders.
#     ses_no_dir: bool
#         if set to True, source dataset will not be
#         expected to have session folders.
#     data_dirs: dict
#         dictionary containing list of folders with
#         recording data as key and data type as value.
#         If folder contain several types of data,
#         then value must be set to empty string
#     dry_run: bool
#         if set to True, no disk writing operations
#         will be performed

# %% [markdown]
# The two mandatory arguments `source` and `destination` are the paths
# to the unbidsified dataset and to the prepared dataset, respectively.
# These paths are stored in `SOURCE_PATH` and `PREPARED_PATH`:

# %% [markdown]
# ### Getting logger report

# %% [markdown]
# The main goal of the `bidsme.init()` function is to setup logging:

# %%
help(bidsme.init)
# Out:
# Help on function init in module bidsme.main:
#
# init(
#     level='INFO',
#     formatter='%(name)s(%(lineno)d) - %(levelname)s %(message)s',
#     quiet=False,
#     log_dir='',
#     schema_path=None
# )
#     Initialize logger and prints out bidsme header
#
#     Parameters:
#     -----------
#     level: str
#         Verbosity level of logger
#     formatter: str
#         Formatter string of logger
#     quiet: bool
#         If true, all terminal output are supressed,
#         but log is still written to log file
#     log_dir: str
#         Directory where the log file is placed,
#         if empty, no log file is written
#     schema_path: str
#         Path to alternative bids schema directory
#
#     Returns:
#     --------
#     logger:
#         the initialized logger object

# %% [markdown]
# The `level` and `formatter` parameters allow to setup the
# [verbosity level](https://docs.python.org/3/library/logging.html#logging-levels)
# and the [format](https://docs.python.org/3/library/logging.html#logrecord-attributes)
# of logging string.

# %% [markdown]
# The `log_dir` parameterer, if specified, will save all logging messages in
# provided directory.

# %% [markdown]
# The `bidsme.init()` returns a [logger object](https://docs.python.org/3/library/logging.html),
# manipulating which allows to change logging level without re-running `bidsme.init()`:

# %%
logger.setLevel("WARNING")
bidsme.prepare(SOURCE_PATH, PREPARED_PATH)
# Out:
# bidsme.prepare(338) - WARNING Unable to identify data in folder /data/pt_02262/bids_test/bids_folders/source/41006.a1/20230606
# bidsme.prepare(338) - WARNING Unable to identify data in folder /data/pt_02262/bids_test/bids_folders/source/41006.a1/20231012
# bidsme.prepare(338) - WARNING Unable to identify data in folder /data/pt_02262/bids_test/bids_folders/source/41006.a1/20231121
# bidsme.prepare(338) - WARNING Unable to identify data in folder /data/pt_02262/bids_test/bids_folders/source/41006.a1/20231123
# /data/u_kuegler_software/git/bidsme/bidsme/bidsMeta/BidsTable.py:234: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   to_save = self.df[selection]

# %% [markdown]
# The `logger` object also keep in memory the number of warnings and errors,
# the function `bidsme.tools.info.reporterrors()` will show these counts:

# %%
logger.setLevel("INFO")
bidsme.tools.info.reporterrors(logger)
# Out:
# main(148) - INFO counthangler:{'WARNING': 4}
# 0

# %% [markdown]
# The counter will increase at each call of bidsme functions,
# in order to track the errors only from last execution,
# we can reset the counters using `bidsme.tools.info,reseterrors()`:

# %%
bidsme.tools.info.reseterrors(logger)
bidsme.tools.info.reporterrors(logger)
# Out:
# main(148) - INFO counthangler:{}
# 0

# %% [markdown]
# ### Data retrieval

# %% [markdown]
# Bidsme expects a naive organisation of source dataset:
# ```
# $SOURCE_PATH/<subject folder>/<session folder>/<data files>
# ```
#
# In the example dataset, this corresponds to:
# - `<subject folder>`: 001, 002, 003, 004 etc.
# - `<session folder>`: s01629, s01599 etc.
#
# The problem with this dataset is that the actual data are stored in `nii` subfolder:

# %% [markdown]
# In this case, the user should communicate this information to bidsme using
# `data_dirs` option, which expects a dictionary with keys of folder names,
# and values the data type of included images.
#
# For example `data_dirs={"nii": "MRI"}` will tell that in `nii` sub-folder
# we have `MRI` images:

# %%
bidsme.prepare(SOURCE_PATH, PREPARED_PATH, data_dirs={"nii/localizer*":"MRI","nii/calc_shims_40mm*":"MRI","nii/t1w_*":"MRI","nii/ernst_*":"MRI","nii/kp_afib1*":"MRI","AAHead*":"MRI","nii/cmrr_noddi*":"MRI","nii/mtw*":"MRI","nii/pdw*":"MRI","nii/semc*":"MRI","nii/tfl*":"MRI"})                             
bidsme.tools.info.reporterrors(logger)
bidsme.tools.info.reseterrors(logger)
# Out:
# bidsme.prepare(192) - INFO -------------- Prepearing data -------------
# bidsme.prepare(193) - INFO Source directory: /data/pt_02262/bids_test/bids_folders/source
# bidsme.prepare(194) - INFO Destination directory: /data/pt_02262/bids_test/bids_folders/renamed
# bidsme.bidsMeta.BidsTable(141) - INFO Created empty participants.tsv table
# bidsme.prepare(295) - INFO Scanning folder /data/pt_02262/bids_test/bids_folders/source/41006.a1/20231121
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (3 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (1 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (1 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (1 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (1 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (1 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (1 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (6 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (10 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (118 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (5 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (5 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (4 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (6 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (6 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (1 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231121' (1 files)
# bidsme.prepare(295) - INFO Scanning folder /data/pt_02262/bids_test/bids_folders/source/41006.a1/20231123
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (3 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (1 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (1 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (1 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (1 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (1 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (1 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (6 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (10 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (2 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (118 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (5 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (5 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (4 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (6 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (6 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (1 files)
# bidsme.prepare(58) - INFO Processing: sub 'sub-41006a1', ses 'ses-20231123' (1 files)
# main(148) - INFO counthangler:{}

# %% [markdown]
# > **CLI:**
# >```bash
# > bidsme prepare $SOURCE_PATH $PREPARED_PATH -r "nii=MRI"
# >```

# %% [markdown]
# The data files from `SOURCE_PATH` are copied into `PREPARED_PATH`
# and organised into bids-like structure: `sub-001/ses-s01513/MRI`:

# %% [markdown]
# The top folder `sub-001` is the subject folder with `sub-` prefix; the name '001' is generated from the name of the `<subject folder>` in the source dataset.
#
# The first subfolder `ses-s01513` is the session folder with `ses-` prefix;
# the name is generated from the name of the `<session folder>` in source dataset.
#
# The second subfolder `MRI` is the data-type folder; it allows to distinguish files
# from differnt modalities, like `MRI`, `PET` or `EEG`; the data type was indicated by the user with `-r` or `--recfolder` option. If not specified by the user, information on data type is retrieved directly from the source data.
#
# Finally, the last hierarchical subfolder `006-cmrr_mbep2d_bold_mb2_invertpe` is the "series"
# folder which contains all images taken during one acquisition or series.
# The name of the folder is composed of two parts:
# - the number of acquisition in the current session
# (the value and meaning of the number depends on the data type;
# in the case of MRI, it corresponds to the series number)
# - the name of aquisition
# (the value and meaning of the number depends on the data type;
# if not defined, it will be the same as the name of data file)
#
# Files that share the same number and name of acquisition will be considered as part of the same series.
#
# > **Important**: Images in some data formats are consistent of several files.
# For example an EEG recording stored in BrainVision format usually consists of 3 files:
# `.vhdr`, `.vmrk` and `.eeg`. Another example is the MRI nifti images associated with a `.json`
# file containing the metadata extracted from DICOM header.
# >
# >`bidsme` view such files as one entity, and in what follows the "file" or "image" will refer
# to full set of files corresponding to same image.

# %% [markdown]
# ## 2 - Table of participants

# %% [markdown]
# The BIDS standard requires that each dataset contains a
# [table](https://bids-specification.readthedocs.io/en/stable/03-modality-agnostic-files.html#participants-file)
# with the list of participants and some basic demographic data.
#
# For convenience, this table is created by 'bidsme' during the preparation step.
# By default, the table file contains only one column `participant_id`, and serves as
# record keeper of the already prepared subjects.
# During this step, 'bidsme' will also automatically create the description file `participants.json`.

# %% [markdown]
# **participants.tsv**: file with basic demographic data

# %%
import pandas
pandas.read_csv(open(os.path.join(PREPARED_PATH, 'participants.tsv')), sep='\t')
# Out:
#   participant_id
# 0        sub-001
# 1        sub-002
# 2        sub-003
# 3        sub-004

# %% [markdown]
# **participants.json**: description of the demographic file

# %%
pandas.read_json(open(os.path.join(PREPARED_PATH, 'participants.json')))
# Out:
#                                          participant_id
# LongName                                 Participant Id
# Description  Unique label associated with a participant

# %% [markdown]
# ### Adding information to the participants.tsv file

# %% [markdown]
# In order to add additional columns, `bidsme` needs a template `.json` file,
# which is just a sidecar json file for participants
# (see [documentation](https://bids-specification.readthedocs.io/en/stable/03-modality-agnostic-files.html#participants-file) for examples).
# An example of such file for the tutorial dataset can be found in the `resources` folder, e.g. `participants.json`:

# %%
pandas.read_json(open(os.path.join(RESOURCES_PATH, 'participants.json')))
# Out:
#                                      participant_id               age  \
# LongName                             Participant Id               Age
# Description  label identifying a particular subject  Age of a subject
# Units                                           NaN              year
# Levels                                          NaN               NaN
#
#                                       sex        education  \
# LongName                              Sex  Education level
# Description              Sex of a subject  Education level
# Units                                 NaN              NaN
# Levels       {'F': 'Female', 'M': 'Male'}              NaN
#
#                                                     group  \
# LongName                                            group
# Description                         Group subject belongs
# Units                                                 NaN
# Levels       {'patient': 'patient', 'control': 'control'}
#
#                                              handiness  \
# LongName                          Handiness of subject
# Description                                        NaN
# Units                                              NaN
# Levels       {'r': 'right-handed', 'l': 'left-handed'}
#
#                                           paired  \
# LongName                               Paired Id
# Description  Subject Id paired with this subject
# Units                                        NaN
# Levels                                       NaN
#
#                                                          ses_1  \
# LongName                                         First session
# Description           Id of the first session taken by subject
# Units                                                      NaN
# Levels       {'ses-LCL': 'Low charge level', 'ses-HCL': 'Hi...
#
#                                                          ses_2  \
# LongName                                        Second session
# Description          Id of the second session taken by subject
# Units                                                      NaN
# Levels       {'ses-LCL': 'Low charge level', 'ses-HCL': 'Hi...
#
#                                                          ses_3
# LongName                                         Third session
# Description          Id of the second session taken by subject
# Units                                                      NaN
# Levels       {'ses-LCL': 'Low charge level', 'ses-HCL': 'Hi...

# %% [markdown]
# This template can be passed to `bidsme` using `--part-template` option:

# %%
bidsme.prepare(SOURCE_PATH, PREPARED_PATH,
               part_template=os.path.join(RESOURCES_PATH, "participants.json"),
               data_dirs={"nii":"MRI"})
bidsme.tools.info.reporterrors(logger)
bidsme.tools.info.reseterrors(logger)
# Out:
# bidsme.prepare(192) - INFO -------------- Prepearing data -------------
# bidsme.prepare(193) - INFO Source directory: /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source
# bidsme.prepare(194) - INFO Destination directory: /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/renamed
# bidsme.bidsMeta.BidsTable(128) - ERROR participants.tsv: Columns ['age', 'sex', 'education', 'group', 'paired', 'ses_1', 'ses_2', 'ses_3'] not found in table
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 bidsme.prepare(SOURCE_PATH, PREPARED_PATH,
#       2                part_template=os.path.join(RESOURCES_PATH, "participants.json"),
#       3                data_dirs={"nii":"MRI"})
#       4 bidsme.tools.info.reporterrors(logger)
#       5 bidsme.tools.info.reseterrors(logger)
#
# File /data/u_kuegler_software/git/bidsme/bidsme/prepare.py:238, in prepare(source, destination, plugin_file, plugin_opt, sub_list, sub_skip_tsv, sub_skip_dir, ses_skip_dir, part_template, sub_prefix, ses_prefix, sub_no_dir, ses_no_dir, data_dirs, dry_run)
#     233         part_template = os.path.join(paths.templates,
#     234                                      "participants.json"
#     235                                      )
#     236 BidsSession.loadSubjectFields(part_template)
# --> 238 sub_table = BidsTable(os.path.join(destination, "participants.tsv"),
#     239                       definitionsFile=part_template,
#     240                       index="participant_id",
#     241                       duplicatedFile="__duplicated.tsv",
#     242                       checkDefinitions=True)
#     244 ################
#     245 # Subject loop #
#     246 ################
#     247 sub_prefix_dir, sub_prefix = os.path.split(sub_prefix)
#
# File /data/u_kuegler_software/git/bidsme/bidsme/bidsMeta/BidsTable.py:130, in BidsTable.__init__(self, table, index, definitionsFile, duplicatedFile, checkDefinitions)
#     127 if checkDefinitions:
#     128     logger.error("{}: Columns {} not found in table"
#     129                  .format(self._name, mismatch))
# --> 130     raise KeyError(mismatch)
#     131 else:
#     132     for c in mismatch:
#
# KeyError: ['age', 'sex', 'education', 'group', 'paired', 'ses_1', 'ses_2', 'ses_3']

# %% [markdown]
# > **CLI:**
# > `bidsme prepare <source> <destination> --part-template <participants.json> -r "nii=MRI"`

# %% [markdown]
# If prepared dataset already contains `participants.tsv`, and the columns are different from
# the ones described in template, the preparation step will fail:
#
# **Error:**
# ```
# bidsMeta.BidsTable(125) - ERROR participants.tsv: Columns ['age', 'sex', 'education', 'group', 'handiness', 'paired', 'ses_1', 'ses_2', 'ses_3'] not found in table
# ```
#
# This is done to maintain participants table consistent for all participants.
#
# >To correct this error, the table in the prepared dataset must have columns sychronized to the template
# and already filled for the already processed participants.
# >
# >An alternative would consist in just removing the `participants.tsv`, as done by
# `clean_data` function, defined in [path definition notebook](../Installation/bidsme_path.ipynb)

# %%
clean_data(PREPARED_PATH)

# %% [markdown]
# Once the conflicts in the table are fixed, the `prepare` step should work:

# %%
bidsme.prepare(SOURCE_PATH, PREPARED_PATH,
               part_template=os.path.join(RESOURCES_PATH, "participants.json"),
               data_dirs={"nii": "MRI"})
bidsme.tools.info.reporterrors(logger)
bidsme.tools.info.reseterrors(logger)
# Out:
# bidsme.prepare(192) - INFO -------------- Prepearing data -------------
# bidsme.prepare(193) - INFO Source directory: /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source
# bidsme.prepare(194) - INFO Destination directory: /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/renamed
# bidsme.bidsMeta.BidsTable(141) - INFO Created empty participants.tsv table
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/001/s01512
# bidsme.prepare(58) - INFO Processing: sub 'sub-001', ses 'ses-s01512' (28 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/001/s01513
# bidsme.prepare(58) - INFO Processing: sub 'sub-001', ses 'ses-s01513' (41 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/001/s01530
# bidsme.prepare(58) - INFO Processing: sub 'sub-001', ses 'ses-s01530' (66 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/002/s01545
# bidsme.prepare(58) - INFO Processing: sub 'sub-002', ses 'ses-s01545' (66 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/002/s01558
# bidsme.prepare(58) - INFO Processing: sub 'sub-002', ses 'ses-s01558' (28 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/002/s01565
# bidsme.prepare(58) - INFO Processing: sub 'sub-002', ses 'ses-s01565' (41 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/003/s01583
# bidsme.prepare(58) - INFO Processing: sub 'sub-003', ses 'ses-s01583' (66 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/003/s01584
# bidsme.prepare(58) - INFO Processing: sub 'sub-003', ses 'ses-s01584' (41 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/003/s01599
# bidsme.prepare(58) - INFO Processing: sub 'sub-003', ses 'ses-s01599' (28 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/004/s01605
# bidsme.prepare(58) - INFO Processing: sub 'sub-004', ses 'ses-s01605' (66 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/004/s01611
# bidsme.prepare(58) - INFO Processing: sub 'sub-004', ses 'ses-s01611' (28 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/004/s01629
# bidsme.prepare(58) - INFO Processing: sub 'sub-004', ses 'ses-s01629' (41 files)
# main(148) - INFO counthangler:{'ERROR': 2}

# %% [markdown]
# If the prepared dataset already contains some data, you may encounter the following
# warning message:
#
# **Warning:**
# ```
# Modules.MRI.hmriNIFTI(233) - WARNING 014-cmrr_mbep2d_diff_NODDI_noise/40: File s1629-0014-00005-000281-01.nii exists at destination
# ```
# This warning just indicates that the files in prepeared dataset are being overwritten.
#
# Now the `participants.json` file in the prepared dataset is updated automatically
# to match the template:

# %%
pandas.read_json(open(os.path.join(PREPARED_PATH, 'participants.json')))
# Out:
#                                      participant_id               age  \
# LongName                             Participant Id               Age
# Description  label identifying a particular subject  Age of a subject
# Units                                           NaN              year
# Levels                                          NaN               NaN
#
#                                       sex        education  \
# LongName                              Sex  Education level
# Description              Sex of a subject  Education level
# Units                                 NaN              NaN
# Levels       {'F': 'Female', 'M': 'Male'}              NaN
#
#                                                     group  \
# LongName                                            group
# Description                         Group subject belongs
# Units                                                 NaN
# Levels       {'patient': 'patient', 'control': 'control'}
#
#                                           paired  \
# LongName                               Paired Id
# Description  Subject Id paired with this subject
# Units                                        NaN
# Levels                                       NaN
#
#                                                          ses_1  \
# LongName                                         First session
# Description           Id of the first session taken by subject
# Units                                                      NaN
# Levels       {'ses-LCL': 'Low charge level', 'ses-HCL': 'Hi...
#
#                                                          ses_2  \
# LongName                                        Second session
# Description          Id of the second session taken by subject
# Units                                                      NaN
# Levels       {'ses-LCL': 'Low charge level', 'ses-HCL': 'Hi...
#
#                                                          ses_3
# LongName                                         Third session
# Description          Id of the second session taken by subject
# Units                                                      NaN
# Levels       {'ses-LCL': 'Low charge level', 'ses-HCL': 'Hi...

# %% [markdown]
# The  `participants.tsv` contains now all the columns defined in template,
# including age, sex, education etc.
#
# The values for all subjects are `n/a` -- not available;
# these values are supposed to be filled either manually or using plugins,
# as it will be demonstrated in a dedicated [tutorial](04-advanced-preparation.ipynb).
#
# > BIDS require to use `n/a` as indicator of missing/non defined values. These values are parced as `NaN` by pandas.

# %%
pandas.read_csv(open(os.path.join(PREPARED_PATH, 'participants.tsv')), sep='\t')
# Out:
#   participant_id  age  sex  education  group  paired  ses_1  ses_2  ses_3
# 0        sub-001  NaN  NaN        NaN    NaN     NaN    NaN    NaN    NaN
# 1        sub-002  NaN  NaN        NaN    NaN     NaN    NaN    NaN    NaN
# 2        sub-003  NaN  NaN        NaN    NaN     NaN    NaN    NaN    NaN
# 3        sub-004  NaN  NaN        NaN    NaN     NaN    NaN    NaN    NaN

# %% [markdown]
# ### Resolving conflicts in `participants.tsv`

# %% [markdown]
# `bidsme` tracks also values in the `participants.tsv` table,
# and will report any inconsistency, for example if same subject
# previously was reported as left-handed and now reported as right-handed.
#
# To demonstrate this, you can manually change some values in `participants.tsv`
# and re-run the preparation step:

# %%
bidsme.prepare(SOURCE_PATH, PREPARED_PATH,
               data_dirs={"nii":"MRI"})
bidsme.tools.info.reporterrors(logger)
bidsme.tools.info.reseterrors(logger)
# Out:
# bidsme.prepare(192) - INFO -------------- Prepearing data -------------
# bidsme.prepare(193) - INFO Source directory: /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source
# bidsme.prepare(194) - INFO Destination directory: /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/renamed
# bidsme.bidsMeta.BidsTable(134) - INFO Loaded participants.tsv table with 4 entries
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/001/s01512
# bidsme.prepare(58) - INFO Processing: sub 'sub-001', ses 'ses-s01512' (28 files)
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 002-cmrr_mbep2d_bold_mb2_invertpe/0: File f1512-0002-00001-000001-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 002-cmrr_mbep2d_bold_mb2_invertpe/1: File f1512-0002-00002-000002-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 002-cmrr_mbep2d_bold_mb2_invertpe/2: File f1512-0002-00003-000003-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 002-cmrr_mbep2d_bold_mb2_invertpe/3: File f1512-0002-00004-000004-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 002-cmrr_mbep2d_bold_mb2_invertpe/4: File f1512-0002-00005-000005-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 004-cmrr_mbep2d_bold_mb2_task_nfat/5: File f1512-0004-00001-000001-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 004-cmrr_mbep2d_bold_mb2_task_nfat/6: File f1512-0004-00002-000002-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 004-cmrr_mbep2d_bold_mb2_task_nfat/7: File f1512-0004-00003-000003-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 004-cmrr_mbep2d_bold_mb2_task_nfat/8: File f1512-0004-00004-000004-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 004-cmrr_mbep2d_bold_mb2_task_nfat/9: File f1512-0004-00005-000005-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 006-cmrr_mbep2d_bold_mb2_invertpe/10: File f1512-0006-00001-000001-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 006-cmrr_mbep2d_bold_mb2_invertpe/11: File f1512-0006-00002-000002-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 006-cmrr_mbep2d_bold_mb2_invertpe/12: File f1512-0006-00003-000003-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 006-cmrr_mbep2d_bold_mb2_invertpe/13: File f1512-0006-00004-000004-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 006-cmrr_mbep2d_bold_mb2_invertpe/14: File f1512-0006-00005-000005-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 008-cmrr_mbep2d_bold_mb2_rest/15: File f1512-0008-00001-000001-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 008-cmrr_mbep2d_bold_mb2_rest/16: File f1512-0008-00002-000002-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 008-cmrr_mbep2d_bold_mb2_rest/17: File f1512-0008-00003-000003-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 008-cmrr_mbep2d_bold_mb2_rest/18: File f1512-0008-00004-000004-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 008-cmrr_mbep2d_bold_mb2_rest/19: File f1512-0008-00005-000005-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 001-localizer/20: File s1512-0001-00001-000001-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 001-localizer/21: File s1512-0001-00001-000002-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 001-localizer/22: File s1512-0001-00001-000003-01.nii exists at destination
# bidsme.Modules.MRI.hmriNIFTI(232) - WARNING 010-gre_field_mapping
data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/renamed/participants.tsv

# %% [markdown]
# **participants.tsv** contains all subjects without conflicts

# %%
pandas.read_csv(open(os.path.join(PREPARED_PATH, 'participants.tsv')), sep='\t')
# Out:
#   participant_id  age  sex  education  group  paired  ses_1  ses_2  ses_3
# 0        sub-001  NaN  NaN        NaN    NaN     NaN    NaN    NaN    NaN
# 1        sub-002  NaN  NaN        NaN    NaN     NaN    NaN    NaN    NaN
# 2        sub-003  NaN  NaN        NaN    NaN     NaN    NaN    NaN    NaN
# 3        sub-004  NaN  NaN        NaN    NaN     NaN    NaN    NaN    NaN

# %% [markdown]
# **__duplicated.tsv** contains the original entry and the new entries for
# the each subject with conflicts:

# %%
pandas.read_csv(open(os.path.join(PREPARED_PATH, '__duplicated.tsv')), sep='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 pandas.read_csv(open(os.path.join(PREPARED_PATH, '__duplicated.tsv')), sep='\t')
#
# File ~/miniforge3/envs/bidsme/lib/python3.13/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/renamed/__duplicated.tsv'

# %% [markdown]
# To resolve the conflict, you just need to move the correct entries from
# the `__duplictaed.tsv` into the `participants.tsv`,
# then remove the `__duplicated.tsv`.

# %% [markdown]
# > **Note:** The option `--part-template` may be used only once, to create the initial table; for later runs,
# `bidsme` will load the template directly from the `participants.json` file in the prepared dataset.

# %% [markdown]
# ## 3 - Running on subset of subjects

# %% [markdown]
# By default `bidsme` runs on all discovereded sujects in the source dataset,
# but sometimes you will be needed to run only on the selected ones.

# %% [markdown]
# Conviently, the `prepare` function can be run only on a selected subset of participants
# from source dataset using one of the following options:

# %% [markdown]
# ```
# sub_list: list
#         list of subject to process. Subjects
#         are checked after plugin and must
#         start with 'sub-', as in destination
#         folder
#     sub_skip_tsv: bool
#         if set to True, subjects found in
#         destination/participants.tsv will be
#         ignored
#     sub_skip_dir: bool
#         if set to true, subjects with already
#         created directories will be ignored
#         Can conflict with sub_no_dir
#     ses_skip_dir: bool
#         if set to True, sessions with already
#         created directories will be ignored
#         Can conflict with ses_no_dir
# ```

# %% [markdown]
# >**CLI**
# >```
# --participants ID [ID ...]
#                         Space-separated list of subjects to process, as
#                         defined in source folder (i.e. before affecting by
#                         plugin) (default: None)
#   --skip-in-tsv         Skip participants that exists in the participants.tsv
#                         file in destination dataset. (default: False)
#   --skip-existing       Skip participants with corresponding folders exists in
#                         destination dataset. (default: False)
#   --skip-existing-sessions
#                         Skip sessions that exists in destination dataset.
#                         (default: False)
# >```

# %% [markdown]
# For example, in order to run only on third subject, it's enough to add to previous `prepare()`
# function an option `sub_list=[sub-003]` (Note that the subject id is in it's bidsified form, containing `sub-`.):

# %% [markdown]
# ### Providing explicit list of participants

# %% [markdown]
# The `--participants`, followed by a list of subject ids will tell `bidsme` to run only
# on the specified subjects.
#
# For example, if we want to run the preparation step only for subject `003` we can add
# `--participant sub-003`.
#
# > **Note that the provoded sunbject id must starts with `sub-`, in other words, you need
# to give the bidsified subject id.**

# %%
clean_data(PREPARED_PATH)
bidsme.prepare(SOURCE_PATH, PREPARED_PATH,
               part_template=os.path.join(RESOURCES_PATH, "participants.json"),
               data_dirs={"nii": "MRI"},
               sub_list=["sub-003", "sub-004"])
bidsme.tools.info.reporterrors(logger)
bidsme.tools.info.reseterrors(logger)
# Out:
# bidsme.prepare(192) - INFO -------------- Prepearing data -------------
# bidsme.prepare(193) - INFO Source directory: /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source
# bidsme.prepare(194) - INFO Destination directory: /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/renamed
# bidsme.bidsMeta.BidsTable(141) - INFO Created empty participants.tsv table
# bidsme.prepare(280) - INFO Skipping subject 'sub-001'
# bidsme.prepare(280) - INFO Skipping subject 'sub-002'
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/003/s01583
# bidsme.prepare(58) - INFO Processing: sub 'sub-003', ses 'ses-s01583' (66 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/003/s01584
# bidsme.prepare(58) - INFO Processing: sub 'sub-003', ses 'ses-s01584' (41 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/003/s01599
# bidsme.prepare(58) - INFO Processing: sub 'sub-003', ses 'ses-s01599' (28 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/004/s01605
# bidsme.prepare(58) - INFO Processing: sub 'sub-004', ses 'ses-s01605' (66 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/004/s01611
# bidsme.prepare(58) - INFO Processing: sub 'sub-004', ses 'ses-s01611' (28 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/004/s01629
# bidsme.prepare(58) - INFO Processing: sub 'sub-004', ses 'ses-s01629' (41 files)
# main(148) - INFO counthangler:{}

# %% [markdown]
# `bidsme` will scan full dataset, and skip all subjectst hat are not in arguments of `sub_list`.
#
# ```
# prepare(280) - INFO Skipping subject 'sub-001'
# ```
#
# All subjects are skipped, except the requested one:

# %%
# !ls $PREPARED_PATH
# Out:
# participants.json  participants.tsv  sub-003  sub-004

# %% [markdown]
# Running on a short list of subject is performed in the same way,
# you just need to give that list to `--participants` option:

# %% [markdown]
# > **CLI:**
# > `bidsme prepare <source> <destination> -r "nii=MRI" --part-template <participants.json> --participant sub-001 sub-004`

# %% [markdown]
# Now `renamed` folder should contain only subjects 3 and 4:

# %%
# !ls $PREPARED_PATH
# Out:
# participants.json  participants.tsv  sub-003  sub-004

# %% [markdown]
# ### Skipping already prepeared data

# %% [markdown]
# The switches `sub_skip_tsv`, `sub_skip_dir`, `ses_skip_dir` allow users
# to skip already processed subjects and sessions.

# %% [markdown]
# `sub_skip_tsv=True` will skip all subjects that are present in `participants.tsv` file.
#
# In this example, it will skip subjects 3, and 4, and will only run on the second subject:

# %%
bidsme.prepare(SOURCE_PATH, PREPARED_PATH,
               part_template=os.path.join(RESOURCES_PATH, "participants.json"),
               data_dirs={"nii": "MRI"},
               sub_skip_tsv=True)
bidsme.tools.info.reporterrors(logger)
bidsme.tools.info.reseterrors(logger)
# Out:
# bidsme.prepare(192) - INFO -------------- Prepearing data -------------
# bidsme.prepare(193) - INFO Source directory: /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source
# bidsme.prepare(194) - INFO Destination directory: /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/renamed
# bidsme.bidsMeta.BidsTable(134) - INFO Loaded participants.tsv table with 2 entries
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/001/s01512
# bidsme.prepare(58) - INFO Processing: sub 'sub-001', ses 'ses-s01512' (28 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/001/s01513
# bidsme.prepare(58) - INFO Processing: sub 'sub-001', ses 'ses-s01513' (41 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/001/s01530
# bidsme.prepare(58) - INFO Processing: sub 'sub-001', ses 'ses-s01530' (66 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/002/s01545
# bidsme.prepare(58) - INFO Processing: sub 'sub-002', ses 'ses-s01545' (66 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/002/s01558
# bidsme.prepare(58) - INFO Processing: sub 'sub-002', ses 'ses-s01558' (28 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/002/s01565
# bidsme.prepare(58) - INFO Processing: sub 'sub-002', ses 'ses-s01565' (41 files)
# bidsme.prepare(280) - INFO Skipping subject 'sub-003'
# bidsme.prepare(280) - INFO Skipping subject 'sub-004'
# main(148) - INFO counthangler:{}

# %% [markdown]
# > **CLI:**
# `bidsme prepare <source> <destination> -r "nii=MRI" --skip-in-tsv`

# %% [markdown]
# Now the prepared dataset should contain also the missing second subject:

# %%
# !ls $PREPARED_PATH
# Out:
# participants.json  participants.tsv  sub-001  sub-002  sub-003	sub-004

# %% [markdown]
# Parameters `--skip-existing` and `--skip-existing-sessions` will skip subjects and
# sessions, respectively, that already have their folders in prepared dataset.
#
# Please, remove `sub-002` and `sub-003/ses-s01584` folders from prepared dataset:

# %%
shutil.rmtree(os.path.join(PREPARED_PATH, 'sub-002'))
shutil.rmtree(os.path.join(PREPARED_PATH, 'sub-003', 'ses-s01584'))

# %% [markdown]
# Then run the `prepare` step asking to skip existing subjects:

# %%
bidsme.prepare(SOURCE_PATH, PREPARED_PATH,
               part_template=os.path.join(RESOURCES_PATH, "participants.json"),
               data_dirs={"nii": "MRI"},
               sub_skip_dir=True)
bidsme.tools.info.reporterrors(logger)
bidsme.tools.info.reseterrors(logger)
# Out:
# bidsme.prepare(192) - INFO -------------- Prepearing data -------------
# bidsme.prepare(193) - INFO Source directory: /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source
# bidsme.prepare(194) - INFO Destination directory: /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/renamed
# bidsme.bidsMeta.BidsTable(134) - INFO Loaded participants.tsv table with 4 entries
# bidsme.prepare(280) - INFO Skipping subject 'sub-001'
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/002/s01545
# bidsme.prepare(58) - INFO Processing: sub 'sub-002', ses 'ses-s01545' (66 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/002/s01558
# bidsme.prepare(58) - INFO Processing: sub 'sub-002', ses 'ses-s01558' (28 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/002/s01565
# bidsme.prepare(58) - INFO Processing: sub 'sub-002', ses 'ses-s01565' (41 files)
# bidsme.prepare(280) - INFO Skipping subject 'sub-003'
# bidsme.prepare(280) - INFO Skipping subject 'sub-004'
# main(148) - INFO counthangler:{}

# %% [markdown]
# > **CLI:** `bidsme prepare <source> <destination> -r "nii=MRI" --skip-existing`

# %% [markdown]
# The `sub-002` folder should now be recreated in prepared dataset,
# but session `ses-s01584` are still missing, because subject `sub-003`
# already has been processed:

# %%
# !ls $PREPARED_PATH
# !ls $PREPARED_PATH/sub-003
# Out:
# participants.json  participants.tsv  sub-001  sub-002  sub-003	sub-004
# ses-s01583  ses-s01599

# %% [markdown]
# Running next command should restore missing session:

# %%
bidsme.prepare(SOURCE_PATH, PREPARED_PATH,
               part_template=os.path.join(RESOURCES_PATH, "participants.json"),
               data_dirs={"nii": "MRI"},
               ses_skip_dir=True)
bidsme.tools.info.reporterrors(logger)
bidsme.tools.info.reseterrors(logger)
# Out:
# bidsme.prepare(192) - INFO -------------- Prepearing data -------------
# bidsme.prepare(193) - INFO Source directory: /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source
# bidsme.prepare(194) - INFO Destination directory: /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/renamed
# bidsme.bidsMeta.BidsTable(134) - INFO Loaded participants.tsv table with 4 entries
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/001/s01512
# bidsme.prepare(319) - INFO Skipping session 'ses-s01512'
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/001/s01513
# bidsme.prepare(319) - INFO Skipping session 'ses-s01513'
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/001/s01530
# bidsme.prepare(319) - INFO Skipping session 'ses-s01530'
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/002/s01545
# bidsme.prepare(319) - INFO Skipping session 'ses-s01545'
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/002/s01558
# bidsme.prepare(319) - INFO Skipping session 'ses-s01558'
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/002/s01565
# bidsme.prepare(319) - INFO Skipping session 'ses-s01565'
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/003/s01583
# bidsme.prepare(319) - INFO Skipping session 'ses-s01583'
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/003/s01584
# bidsme.prepare(58) - INFO Processing: sub 'sub-003', ses 'ses-s01584' (41 files)
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/003/s01599
# bidsme.prepare(319) - INFO Skipping session 'ses-s01599'
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/004/s01605
# bidsme.prepare(319) - INFO Skipping session 'ses-s01605'
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/004/s01611
# bidsme.prepare(319) - INFO Skipping session 'ses-s01611'
# bidsme.prepare(295) - INFO Scanning folder /data/tu_kuegler/bidsme_tutorial/bidsme_examples/example1/source/004/s01629
# bidsme.prepare(319) - INFO Skipping session 'ses-s01629'
# main(148) - INFO counthangler:{}

# %% [markdown]
# > **CLI:** `bidsme prepare <source> <destination> -r "nii=MRI" --skip-existing-session`

# %% [markdown]
# All sessions should be skipped:
# ```
# prepare(319) - INFO Skipping session 'ses-s01512'
# ```
# except the `ses-s01584`:
# ```
# prepare(59) - INFO Processing: sub 'sub-003', ses 'ses-s01584' (41 files)
# ```
#
# And the session `ses-s01584` is in it's place:

# %%
# !ls $PREPARED_PATH/sub-003
# Out:
# ses-s01583  ses-s01584	ses-s01599

# %% [markdown]
# ## 4 - Prepared dataset

# %% [markdown]
# If all steps above was succesful, we should have a newly created "prepared" dataset,
# which contains all four processed subjects, and demographics table `participants.tsv`:

# %%
# !ls $PREPARED_PATH
# Out:
# participants.json  participants.tsv  sub-001  sub-002  sub-003	sub-004

# %% [markdown]
# For now, each subject has the same id, as the name of folder in the source dataset,
# and the `participants.tsv` table remains unfilled.
# The subject names can be changed and the table can be filled by using plug-ins,
# as described in [advanced prepare tutorial](04-advanced-preparation.ipynb).

# %% [markdown]
# Going down one level, each subject folder should contain three sessions,
# with criptic names, which again can be renamed using plugins:

# %%
# !ls $PREPARED_PATH/sub-003
# Out:
# ses-s01583  ses-s01584	ses-s01599

# %% [markdown]
# Finally, in eachsession folder, you can see a modality folder `MRI`, containing
# a list of MRI sequences acquired during one session:

# %%
# !ls $PREPARED_PATH/sub-003/ses-s01599/MRI
# Out:
# 001-localizer			    010-gre_field_mapping
# 002-cmrr_mbep2d_bold_mb2_invertpe   011-gre_field_mapping
# 004-cmrr_mbep2d_bold_mb2_task_nfat  012-t1_mpr_sag_p2_iso
# 006-cmrr_mbep2d_bold_mb2_invertpe   013-t2_spc_da-fl_sag_p2_iso
# 008-cmrr_mbep2d_bold_mb2_rest

# %% [markdown]
# Based on this structure, in the [next tutorial](02-basic-mapping.ipynb),
# we will configure the `bidsme`, so it could bidsify the dataset.
